# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\abc\OneDrive\Desktop\anand collage 45 days traning\pandas\machine learning\Used_Bikes.csv")

# %%
# print("C:\Users\abc\OneDrive\Desktop\anand collage 45 days traning\pandas\machine learning\Used_Bikes.csv")

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df['owner']
# Out:
# 0        First Owner
# 1        First Owner
# 2        First Owner
# 3        First Owner
# 4        First Owner
#             ...
# 32643    First Owner
# 32644    First Owner
# 32645    First Owner
# 32646    First Owner
# 32647    First Owner
# Name: owner, Length: 32648, dtype: str

# %%
df['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
df.duplicated().sum()
# Out:
# np.int64(25324)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
df.drop(['bike_name','city'], axis=1, inplace=True)

# %%
char=df.select_dtypes(include='object')
num=df.select_dtypes(exclude='object')
# Out:
# C:\Users\abc\AppData\Local\Temp\ipykernel_19280\2102593220.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   char=df.select_dtypes(include='object')

# %%
num
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
char
# Out:
#             owner            brand
# 0     First Owner              TVS
# 1     First Owner    Royal Enfield
# 2     First Owner          Triumph
# 3     First Owner              TVS
# 4     First Owner           Yamaha
# ...           ...              ...
# 9362  First Owner             Hero
# 9369  First Owner            Bajaj
# 9370  First Owner  Harley-Davidson
# 9371  First Owner            Bajaj
# 9372  First Owner            Bajaj
#
# [7324 rows x 2 columns]

# %%
# char=df.select_dtypes(include='0')
# num=df.select_dtypes(exclude='0')

# %%
num
# Out:
#          price  kms_driven  age  power
# 0      35000.0     17654.0  3.0  110.0
# 1     119900.0     11000.0  4.0  350.0
# 2     600000.0       110.0  8.0  675.0
# 3      65000.0     16329.0  4.0  180.0
# 4      80000.0     10000.0  3.0  150.0
# ...        ...         ...  ...    ...
# 9362   25000.0     48587.0  8.0  150.0
# 9369   35000.0     60000.0  9.0  220.0
# 9370  450000.0      3430.0  4.0  750.0
# 9371  139000.0     21300.0  4.0  400.0
# 9372   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 4 columns]

# %%
char
# Out:
#             owner            brand
# 0     First Owner              TVS
# 1     First Owner    Royal Enfield
# 2     First Owner          Triumph
# 3     First Owner              TVS
# 4     First Owner           Yamaha
# ...           ...              ...
# 9362  First Owner             Hero
# 9369  First Owner            Bajaj
# 9370  First Owner  Harley-Davidson
# 9371  First Owner            Bajaj
# 9372  First Owner            Bajaj
#
# [7324 rows x 2 columns]

# %%
char['owner'].unique()
# Out:
# <StringArray>
# ['First Owner', 'Second Owner', 'Third Owner', 'Fourth Owner Or More']
# Length: 4, dtype: str

# %%
owner_dict={'First Owner':1, 'Second Owner':2, 'Third Owner':3, 'Fourth Owner Or More':4}
char['owner']=char['owner'].map(owner_dict)

# %%
char
# Out:
#       owner            brand
# 0         1              TVS
# 1         1    Royal Enfield
# 2         1          Triumph
# 3         1              TVS
# 4         1           Yamaha
# ...     ...              ...
# 9362      1             Hero
# 9369      1            Bajaj
# 9370      1  Harley-Davidson
# 9371      1            Bajaj
# 9372      1            Bajaj
#
# [7324 rows x 2 columns]

# %%
char['brand'].unique()
# Out:
# <StringArray>
# [            'TVS',   'Royal Enfield',         'Triumph',          'Yamaha',
#            'Honda',            'Hero',           'Bajaj',          'Suzuki',
#          'Benelli',             'KTM',        'Mahindra',        'Kawasaki',
#           'Ducati',         'Hyosung', 'Harley-Davidson',            'Jawa',
#              'BMW',          'Indian',         'Rajdoot',             'LML',
#            'Yezdi',              'MV',           'Ideal']
# Length: 23, dtype: str

# %%
brand_dict={            'TVS':1,   'Royal Enfield':2,         'Triumph':3,          'Yamaha':4,
           'Honda':5,            'Hero':6,           'Bajaj':7,          'Suzuki':8,
         'Benelli':9,             'KTM':10,        'Mahindra':11,        'Kawasaki':12,
          'Ducati':13,         'Hyosung':14, 'Harley-Davidson':15,            'Jawa':16,
             'BMW':17,          'Indian':18,         'Rajdoot':19,             'LML':20,
           'Yezdi':21,              'MV':22,           'Ideal':23}
char['brand']=char['brand'].map(brand_dict)

# %%
char
# Out:
#       owner  brand
# 0         1      1
# 1         1      2
# 2         1      3
# 3         1      1
# 4         1      4
# ...     ...    ...
# 9362      1      6
# 9369      1      7
# 9370      1     15
# 9371      1      7
# 9372      1      7
#
# [7324 rows x 2 columns]

# %%
total_df=pd.concat([char,num],axis=1)

# %%
total_df
# Out:
#       owner  brand     price  kms_driven  age  power
# 0         1      1   35000.0     17654.0  3.0  110.0
# 1         1      2  119900.0     11000.0  4.0  350.0
# 2         1      3  600000.0       110.0  8.0  675.0
# 3         1      1   65000.0     16329.0  4.0  180.0
# 4         1      4   80000.0     10000.0  3.0  150.0
# ...     ...    ...       ...         ...  ...    ...
# 9362      1      6   25000.0     48587.0  8.0  150.0
# 9369      1      7   35000.0     60000.0  9.0  220.0
# 9370      1     15  450000.0      3430.0  4.0  750.0
# 9371      1      7  139000.0     21300.0  4.0  400.0
# 9372      1      7   80000.0      7127.0  5.0  220.0
#
# [7324 rows x 6 columns]

# %%
total_df.duplicated().sum()
# Out:
# np.int64(18)

# %%
total_df.drop_duplicates(inplace=True)

# %%
total_df.isnull().sum()
# Out:
# owner         0
# brand         0
# price         0
# kms_driven    0
# age           0
# power         0
# dtype: int64

# %%
total_df.to_csv("final_clen_bike.csv")

# %%
x=total_df.drop('price',axis=1)

# %%
x
# Out:
#       owner  brand  kms_driven  age  power
# 0         1      1     17654.0  3.0  110.0
# 1         1      2     11000.0  4.0  350.0
# 2         1      3       110.0  8.0  675.0
# 3         1      1     16329.0  4.0  180.0
# 4         1      4     10000.0  3.0  150.0
# ...     ...    ...         ...  ...    ...
# 9362      1      6     48587.0  8.0  150.0
# 9369      1      7     60000.0  9.0  220.0
# 9370      1     15      3430.0  4.0  750.0
# 9371      1      7     21300.0  4.0  400.0
# 9372      1      7      7127.0  5.0  220.0
#
# [7306 rows x 5 columns]

# %%
y=total_df[['price']]

# %%
y
# Out:
#          price
# 0      35000.0
# 1     119900.0
# 2     600000.0
# 3      65000.0
# 4      80000.0
# ...        ...
# 9362   25000.0
# 9369   35000.0
# 9370  450000.0
# 9371  139000.0
# 9372   80000.0
#
# [7306 rows x 1 columns]

# %%
import pandas as pd
import numpy as np
import os
df=pd.read_csv('final_clen_bikes.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[72], line 4
#       1 import pandas as pd
#       2 import numpy as np
#       3 import os
# ----> 4 df=pd.read_csv('final_clen_bikes.csv')
#
# File c:\Users\abc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
tvs_df=df[df['brand']=='TVS']

# %%
tvs_df
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
tvs_first_owner_df =tvs_df[tvs_df['owner']=='First Owner']

# %%
tvs_first_owner_df
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
a=tvs_first_owner_df[tvs_first_owner_df['kms_driven']<=50000]

# %%
a
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
royal_df=df[df['brand']=='Royal Enfield']

# %%
royal_df
# Out:
#                                       bike_name     price  \
# 1                   Royal Enfield Classic 350cc  119900.0
# 8             Royal Enfield Thunderbird X 350cc  145000.0
# 9      Royal Enfield Classic Desert Storm 500cc   88000.0
# 23           Royal Enfield Classic Chrome 500cc  121700.0
# 36                  Royal Enfield Classic 350cc   98800.0
# ...                                         ...       ...
# 32601               Royal Enfield Classic 350cc   95500.0
# 32614        Royal Enfield Bullet Electra 350cc  105000.0
# 32633               Royal Enfield Classic 350cc   87000.0
# 32634           Royal Enfield Thunderbird 350cc   70000.0
# 32639               Royal Enfield Classic 350cc   95500.0
#
#                       city  kms_driven         owner   age  power  \
# 1                    Delhi     11000.0   First Owner   4.0  350.0
# 8                Bangalore      9190.0   First Owner   3.0  350.0
# 9                    Delhi     19000.0  Second Owner   7.0  500.0
# ...

# %%
royal_first_owner_df=royal_df[royal_df['owner']=='First Owner']

# %%
royal_first_owner_df
# Out:
#                                 bike_name     price                 city  \
# 1             Royal Enfield Classic 350cc  119900.0                Delhi
# 8       Royal Enfield Thunderbird X 350cc  145000.0            Bangalore
# 23     Royal Enfield Classic Chrome 500cc  121700.0               Kalyan
# 36            Royal Enfield Classic 350cc   98800.0                Kochi
# 38      Royal Enfield Thunderbird X 500cc  190500.0           Samastipur
# ...                                   ...       ...                  ...
# 32595         Royal Enfield Classic 350cc   87000.0  Gautam Buddha Nagar
# 32601         Royal Enfield Classic 350cc   95500.0                Delhi
# 32614  Royal Enfield Bullet Electra 350cc  105000.0                Delhi
# 32633         Royal Enfield Classic 350cc   87000.0  Gautam Buddha Nagar
# 32639         Royal Enfield Classic 350cc   95500.0                Delhi
#
#        kms_driven        owner  age  power          brand
# ...

# %%
b=royal_first_owner_df[royal_first_owner_df['kms_driven']<=50000]

# %%
b
# Out:
#                                 bike_name     price                 city  \
# 1             Royal Enfield Classic 350cc  119900.0                Delhi
# 8       Royal Enfield Thunderbird X 350cc  145000.0            Bangalore
# 23     Royal Enfield Classic Chrome 500cc  121700.0               Kalyan
# 36            Royal Enfield Classic 350cc   98800.0                Kochi
# 38      Royal Enfield Thunderbird X 500cc  190500.0           Samastipur
# ...                                   ...       ...                  ...
# 32595         Royal Enfield Classic 350cc   87000.0  Gautam Buddha Nagar
# 32601         Royal Enfield Classic 350cc   95500.0                Delhi
# 32614  Royal Enfield Bullet Electra 350cc  105000.0                Delhi
# 32633         Royal Enfield Classic 350cc   87000.0  Gautam Buddha Nagar
# 32639         Royal Enfield Classic 350cc   95500.0                Delhi
#
#        kms_driven        owner  age  power          brand
# ...

# %%
royal_first_owner_df[royal_first_owner_df['age']<=2.0]
# Out:
#                                    bike_name     price         city  \
# 38         Royal Enfield Thunderbird X 500cc  190500.0   Samastipur
# 81           Royal Enfield Interceptor 650cc  260000.0  Navi Mumbai
# 139     Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara
# 157     Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara
# 194              Royal Enfield Electra 350cc  145000.0    Bangalore
# ...                                      ...       ...          ...
# 7694  Royal Enfield Classic Chrome 500cc ABS  215000.0        Delhi
# 7706  Royal Enfield Classic Chrome 500cc ABS  215000.0        Delhi
# 8139   Royal Enfield Thunderbird X 350cc ABS  169000.0    Bangalore
# 8192     Royal Enfield Thunderbird 350cc ABS  145000.0    Ghaziabad
# 8836   Royal Enfield Thunderbird X 350cc ABS  170200.0       Mumbai
#
#       kms_driven        owner  age  power          brand
# 38        4550.0  First Owner  2.0  500.0  Royal Enfield
# ...

# %%
royal_first_owner_df[royal_first_owner_df['price']<=200000]
# Out:
#                                 bike_name     price                 city  \
# 1             Royal Enfield Classic 350cc  119900.0                Delhi
# 8       Royal Enfield Thunderbird X 350cc  145000.0            Bangalore
# 23     Royal Enfield Classic Chrome 500cc  121700.0               Kalyan
# 36            Royal Enfield Classic 350cc   98800.0                Kochi
# 38      Royal Enfield Thunderbird X 500cc  190500.0           Samastipur
# ...                                   ...       ...                  ...
# 32595         Royal Enfield Classic 350cc   87000.0  Gautam Buddha Nagar
# 32601         Royal Enfield Classic 350cc   95500.0                Delhi
# 32614  Royal Enfield Bullet Electra 350cc  105000.0                Delhi
# 32633         Royal Enfield Classic 350cc   87000.0  Gautam Buddha Nagar
# 32639         Royal Enfield Classic 350cc   95500.0                Delhi
#
#        kms_driven        owner  age  power          brand
# ...

# %%
enfield=df[(df['brand']=='Royal Enfield') &(df['kms_driven']<50000)&(df['owner']=='First Owner')&(df['age']<=2)&(df['price']<=200000)]
enfield
# Out:
#                                     bike_name     price          city  \
# 38          Royal Enfield Thunderbird X 500cc  190500.0    Samastipur
# 139      Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 157      Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 194               Royal Enfield Electra 350cc  145000.0     Bangalore
# 222      Royal Enfield Himalayan 410cc Fi ABS  177982.0  Hamirpur(hp)
# ...                                       ...       ...           ...
# 7422  Royal Enfield Himalayan 410cc Sleet ABS  175000.0       Alipore
# 7559               Royal Enfield Bullet 500cc  170000.0         Delhi
# 8139    Royal Enfield Thunderbird X 350cc ABS  169000.0     Bangalore
# 8192      Royal Enfield Thunderbird 350cc ABS  145000.0     Ghaziabad
# 8836    Royal Enfield Thunderbird X 350cc ABS  170200.0        Mumbai
#
#       kms_driven        owner  age  power          brand
# 38        4550.0  First Owner  2.0  500.0  Royal Enfield
# ...

# %%
royal_data=df[(df['brand']=='Royal Enfield')&
              (df['owner']=='First Owner')& 
(df['kms_driven']<=50000)&
(df['age']<=2)&
(df['price']<200000)]

# %%
royal_data
# Out:
#                                     bike_name     price          city  \
# 38          Royal Enfield Thunderbird X 500cc  190500.0    Samastipur
# 139      Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 157      Royal Enfield Himalayan 410cc Fi ABS  173300.0      Vadodara
# 194               Royal Enfield Electra 350cc  145000.0     Bangalore
# 222      Royal Enfield Himalayan 410cc Fi ABS  177982.0  Hamirpur(hp)
# ...                                       ...       ...           ...
# 7422  Royal Enfield Himalayan 410cc Sleet ABS  175000.0       Alipore
# 7559               Royal Enfield Bullet 500cc  170000.0         Delhi
# 8139    Royal Enfield Thunderbird X 350cc ABS  169000.0     Bangalore
# 8192      Royal Enfield Thunderbird 350cc ABS  145000.0     Ghaziabad
# 8836    Royal Enfield Thunderbird X 350cc ABS  170200.0        Mumbai
#
#       kms_driven        owner  age  power          brand
# 38        4550.0  First Owner  2.0  500.0  Royal Enfield
# ...

# %%
df.query("brand=='Royal Enfield' and age <=2.0 and ")
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:3748 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[71], line 1
#     df.query("brand=='Royal Enfield' and age <=2.0 and ")
#
#   File c:\Users\abc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5193 in query
#     res = self.eval(
#
#   File c:\Users\abc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5373 in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File c:\Users\abc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\eval.py:370 in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File c:\Users\abc\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\computation\expr.py:819 in __init__
#     self.terms = self.parse()
#
# ...
